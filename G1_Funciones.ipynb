# %% [markdown]
# # Problema 1

# %% [markdown]
# Una red transmite datos a $100$ megabits por segundo. Crea una función utilizando *Python* que permita calcular la cantidad de datos transmitidos en una cierta cantidad de tiempo (en segundos). Luego utiliza la función y calcula cuántos datos se transmiten en:
#
# * $45$ segundos
# * $1,5$ minutos
# * $1$ hora

# %%
def datos_transmitidos(datos, segundos):
    return datos*segundos

print(f"Datos transmitidos: {datos_transmitidos(100, 45)}")
print(f"Datos transmitidos: {datos_transmitidos(100, 90)}")
print(f"Datos transmitidos: {datos_transmitidos(100, 60*60)}")
# Out:
# Datos transmitidos: 4500
# Datos transmitidos: 9000
# Datos transmitidos: 360000

# %% [markdown]
# # Problema 2

# %% [markdown]
# Utilizando la función definida en el problema $1$, genera un listado que muestre los datos transmitidos para tiempos desde $0$ hasta $1.000$ segundos con incrementos de $100$ segundos.

# %%
for i in range(11): # Itera desde 0 al 10
    c = i*100 # Crea los saltos de 100 en 100

    print(f"Datos transmitidos: {datos_transmitidos(100, c)} en {c} segundos")
# Out:
# Datos transmitidos: 0 en 0 segundos
# Datos transmitidos: 10000 en 100 segundos
# Datos transmitidos: 20000 en 200 segundos
# Datos transmitidos: 30000 en 300 segundos
# Datos transmitidos: 40000 en 400 segundos
# Datos transmitidos: 50000 en 500 segundos
# Datos transmitidos: 60000 en 600 segundos
# Datos transmitidos: 70000 en 700 segundos
# Datos transmitidos: 80000 en 800 segundos
# Datos transmitidos: 90000 en 900 segundos
# Datos transmitidos: 100000 en 1000 segundos

# %% [markdown]
# # Problema 3

# %% [markdown]
# La **latencia** de una red corresponde al tiempo que tarda un paquete de datos en viajar desde el punto de origen al destino. En otras palabras, es el tiempo que transcurre desde que se envía una solicitud de un dispositivo hasta que se recibe una respuesta del servidor u otro dispositivo.
#
# La latencia puede verse afectada por la velocidad de transmisión de los datos a través de los cables o conexiones inalámbricas, la distancia física entre los dispositivos, el tiempo que tarda un computador en procesar o reenviar los datos, etc.
#
# En redes de comunicación, como las videoconferencias, juegos en línea y transmisión de datos en tiempo real, es deseable una baja latencia, de lo contrario pueden existir retrasos en la comunicación y afectar negativamente la experiencia del usuario.

# %% [markdown]
# Según el contexto mencionado, crea una función en *Python* que permita calcular la **latencia real** de una red dada una latencia estimada. Suponga que la latencia real es un $20\%$ mayor a la latencia estimada.
#
# Calcule la latencia real para una latencia estimada de:
#
# a)   $200$ milisegundos.
#
# b)   $149$ milisegundos.
#
# c)   $74$ milisegundos.

# %%
def latenciaReal(tiempo): # Tiempo en milisegundos
    return tiempo*1.20

print(f"Latencia real: {latenciaReal(200)}")
print(f"Latencia real: {latenciaReal(149)}")
print(f"Latencia real: {latenciaReal(74)}")
# Out:
# Latencia real: 240.0
# Latencia real: 178.79999999999998
# Latencia real: 88.8

# %% [markdown]
# # Problema 4

# %% [markdown]
# Como parte de un proyecto de mejora, en el año $2021$ se instaló un cable de fibra óptica que une España con EEUU. El cable tiene un largo de $6.600$ $km$ y fue colocado por un barco a una velocidad de $1,85$ $km/h$.
#
#
#
# 1.   Determine la forma algebraica de la función que permite determinar el largo del cable instalado (en km) a partir del tiempo transcurrido (en horas). Utilice la instrucción *def* para definir la función en *Python*.
# 2.   Defina variable dependiente e independiente, indicando unidad de medida.
# 3.   Determine el dominio contextualizado de la función.
# 4.   Grafique la función utilizando la biblioteca *Matplotlib* considerando el dominio contextualizado.
# 5.   ¿Cuántos metros de cable se instalaron al transcurrir $148$ horas? ¿Y transcurridas $2.300$ horas?
# 6.   Si se han instalado $3.480$ kilometros de cable, ¿cuántas horas llevan de trabajo?
# 7.   ¿Cuánto tiempo transcurrió para que se completara la obra?

# %%
import matplotlib.pyplot as mt
import numpy

# 1. 

def d(t):
    return 1.85*t # formula que nos devuelve la distancia recorrida en cantidad de tiempo

# 2. La variable independiente es t en Horas y dependiente es la distancia medida en Kilometros

# 3. El dominio de la funcion dado por los reales 0 hasta 6600/1.85

dominiox = 6600/1.85

print(f"Dominio: {dominiox:.1f}")

# 5. Para saber esto lo que tenemos que hacer es evaluar la funcion en ambos puntos d(148) y d(2300) y estos dividirlos 
# por 6600

print(f"Por lo que los resultados son para 148 - {d(148)} y para 2300 - {d(2300)}")

# siendo estos valores 0.04 cables colocados y 0.64 cables colocados, ambos valores siendo inferiores a ningun cable colocado
# en su totalidad

# 6. Para conocer este dato debemos calcular 3480/1.85

print(f"Asi que las horas trabajadas para colocar 3480 kilómetros de cable son {3480/1.85}")

# 7. Para esto debemos encontrar el valor de x que nos da exactamente 6600 que es 6600/1.85

print(f"Asi el tiempo maximo de la obra es de {dominiox:.1f}")

# 4.

def generarEjex(dominioMax, intervalo):
    x = numpy.arange(0, dominioMax, intervalo)
    return x

x = generarEjex(dominiox, 1)

y = d(x)

mt.plot(x, y)

mt.xlabel("Tiempo (Horas)")
mt.ylabel("Largo del cable (Kilómetros)")
mt.title("Cantidad de cable colocado en cantidad de tiempo")

mt.grid(True)

mt.show()
# Out:
# Dominio: 3567.6
# Por lo que los resultados son para 148 - 273.8 y para 2300 - 4255.0
# Asi que las horas trabajadas para colocar 3480 kilómetros de cable son 1881.081081081081
# Asi el tiempo maximo de la obra es de 3567.6

# %% [markdown]
# # Problema 5

# %% [markdown]
# Un turista ha llegado a Santiago y desea conocer algunos lugares de la ciudad. Ha decidido visitar el Palacio de la Moneda y desde ahí trasladarse al centro comercial "Costanera Center", utilizando algún medio de transporte que ofrece la ciudad.
#
# Si se traslada en metro deberá abordar en estación La Moneda y bajar en la estación Tobalaba ($9$ estaciones). La función $f(t)$ permite calcular la distancia recorrida utilizando el metro (en kilómetros) transcurridos $t$ minutos.
#
# $$f(t) = 0,4t$$
#
# Si se traslada en bus, el turista podrá observar la ciudad y otros atractivos en su viaje. La función $g(t)$ permite calcular la distancia recorrida en bus (en kilómetros) transcurridos $t$ minutos.
#
# $$g(t) = 0,3t$$
#
# Según la información anterior:
#
# 1. Grafique ambas funciones, indicando el nombre de cada eje junto con su unidad de medida. Para realizar el gráfico utilice la biblioteca *Matplotlib*.
# 2.  Si se sabe que el metro se demora $1,2$ minutos en llegar desde una estación a otra y espera $30$ segundos en cada estación, indique el dominio contextualizado para $f(t)$.
# 3. Mediante análisis gráfico, indique cuál medio de transporte es más conveniente en términos de tiempo, para el turista. Justifique.
# 4.  Si se sabe que desde estación La Moneda hasta Tobalaba son aproximadamente $6$ kilómetros ¿cuántos tiempo tardará el turista en llegar a su destino con cada una de las opciones?

# %%
# 1. 

import matplotlib.pyplot as mt
import numpy

def generar_eje_x(cantidad, dispersion):
    x = numpy.arange(0, cantidad, dispersion)
    return x

# Distancia recorrida

def f(t):
    return 0.4*t

def g(t):
    return 0.3*t

# |---------------------|

x = generar_eje_x(14.8, 0.01)

yf = f(x)
yg = g(x)

mt.plot(x, yf, label = "Metro")
mt.plot(x, yg, label = "Bus")

mt.xlabel("Tiempo (Minutos)")
mt.ylabel("Distancia recorrida (Kilómetros)")

mt.grid(True)

mt.show()

# 2. Tenemos que el metro tiene 9 estaciones, se demora 1.2 minutos entre estaciones y espera 30 segundos por estacion excepto en
# la ultima por lo que tenemos que es 0 a 14.8 minutos el dominio de la funcion

print(f"Asi como el dominio se calcula como 9*1.2+0.5*8 es {9*1.2+0.5*8})

# 3. Tenemos que por un analisis grafico es mas conveniente la funcion f(t) que corresponde al metro siendo mejor 
# al reccorer mas distancia en cantidad de tiempo

# 4. En metro seria para metro 6/0.4 y para bus 6/0.3 dando como resultado 15 minutos para el metro y 20 minutos para
# el bus
# Out:
#   Cell In[11], line 38
#     print(f"Asi como el dominio se calcula como 9*1.2+0.5*8 es {9*1.2+0.5*8})
#           ^
# SyntaxError: unterminated f-string literal (detected at line 38)

# %% [markdown]
# # Problema 6

# %% [markdown]
# La temperatura de un servidor (en °C) puede ser modelada mediante la función
#
# $$T(t) = -0,5 t^{2} + 3 t + 20$$
#
# donde $t$ corresponde al tiempo transcurrido (en horas) en un día laboral. Considere que la jornada laboral comienza a las 08:00 horas y termina a las 17:00 horas.
#
# 1.  Defina variable dependiente e independiente, indicando unidad de medida.
# 2.  Determine el dominio contextualizado del problema.
# 3.  Grafique la función utilizando *Python*.
# 4.  Mediante un análisis gráfico, estime cuándo el servidor alcanza la máxima temperatura y calcule cuánto es.
# 5.  Determine la temperatura del servidor a las 13:00 horas y al finalizar la jornada laboral.

# %%
# 1. La variable independiente es el Tiempo y la dependiente es la temperatura

# 2. El dominio de la función es desde el 0 al 9 incluyendo a ambos

# 4. Sabemos que el maximo se alcanza en 0 = -t+3, con t=3 y asi podemos decir que ese es el maximo de la funcion
# a las 11:00

def T(t):
    return -(1/2)*t**(2)+3*t+20

print(f"Por lo que T(8) su valor es {T(8)}")

# 5. Estos valores son al evaluar la funcion en T(0) y T(9)

print(f"T(5)={T(5)} y T(9)={T(9)}")


# 3. 

import matplotlib.pyplot as mt
import numpy

def generarEjex(dominioMin, dominioMax, intervalo):
    x = numpy.arange(dominioMin, dominioMax, intervalo)
    return x

x = generarEjex(0, 9, 0.01)

y = T(x)

mt.plot(x, y)

mt.xlabel("Tiempo (Horas)")
mt.ylabel("Temperatura de un servidor (°C)")
mt.title("Temperatura por horas de un servidor en una jornada laboral")

mt.grid(True)

mt.show()
# Out:
# Por lo que T(8) su valor es 12.0
# T(5)=22.5 y T(9)=6.5

# %% [markdown]
# # Problema 7

# %% [markdown]
# El número de usuarios de una red social se puede modelar mediante la función:
#
# $$U(t) = \frac{1.000}{1+9e^{-0.5t}}$$
#
# donde $t$ corresponde al tiempo transcurrido en meses.
#
# 1.  Defina variable dependiente e independiente, indicando unidad de medida.
# 2.  Determine la cantidad de usuarios transcurridos $12$ meses.
# 3.  Grafique la función, utilizando la librería *Matplotlib*, para los primeros dos años de funcionamiento.
# 4.  ¿Cuánto tiempo debe pasar para que la red social llegue a $800$ usuarios?

# %%
# 1. la variable independiente es t siendo medida en meses U(t) representa la variable dependiente y se mide en usuarios en unidades

import matplotlib.pyplot as mt
import numpy

def d(t):
    return 1000/(1+9*numpy.exp(-0.5*t))

def generarEjex(dominioMin, dominioMax, intervalo):
    x = numpy.arange(dominioMin, dominioMax, intervalo)
    return x

# 2. Para esto solo basta la funcion evaluarla en 12 cual su resultado es 978 usuarios

print(f"Cantidad de usuarios en 12 meses {d(12):.0f}")

# 4. Para esto debemos resolver la ecuacion 800 = d(t) con t = 7.17 aproximadamente al solucionar la ecuacion exponencial

# con un poco de algebra llegamos a que la solucion que buscamos es t = -2*ln(200/7200)

print(f"El resultado es t = {-2*numpy.log(200/7200):.1f}")

# 3. 

x = generarEjex(0, 24, 0.1)

y = d(x)

mt.plot(x, y)

mt.xlabel("Tiempo (Meses)")
mt.ylabel("Cantidad de usuarios (Usuarios)")
mt.title("Cantidad de usuarios en una red social en meses")

mt.grid(True)

mt.show()
# Out:
# Cantidad de usuarios en 12 meses 978
# El resultado es t = 7.2

# %% [markdown]
# # Problema 8

# %% [markdown]
# El tiempo de ejecución de un algoritmo de ordenación (en segundos) se puede modelar mediante la función:
#
# $$A(n) = 0,01n^{2} + 0,5n + 2$$
#
# donde $n$ corresponde a la cantidad de elementos a ordenar. El algoritmo funciona desde las 23:00 horas hasta las 06:00 horas y debe ordenar $1.562$ elementos.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# 2. Determine el dominio contextualizado de la función.
# 3. Determine el tiempo de ejecución para ordenar $1.200$ elementos.
# 4. Grafique, utilizando la biblioteca *Matplotlib*, la función $A(n)$.
# 5. ¿Cuántos elementos ordena luego de $6$ horas de funcionamiento?

# %%
# 1. La variable independiente es n la cual es la cantidad de elementos a ordenar, por otro lado A(n) es el tiempo
# de ejecucion que depende de la cantidad de elementos

# 2. El dominio contextualizado es desde 0 a 1562 incluyendo a ambos en el intervalo

# 3. Solo basta en evaluar en A(1200)

def A(n):
    return (1/100)*n**2+(1/2)*n+2

print(f"Se demora un total de {A(1200):.1f} segundos")

# 5. Debemos resolver la ecuacion 6*60*60=A(t) que corresponde a 

from scipy.optimize import fsolve

def a(n):
    return ((1/100)*n**2+(1/2)*n+2) - 6*60*60

n = numpy.linspace(0, 1562, 1)

sol = fsolve(a, n)

print(f"Ordena una cantidad de {sol[0]:.0f} elementos  ")

# 4. 

x = generarEjex(0, 1562, 1)

y = A(x)

mt.plot(x, y)

mt.xlabel("Elementos ordenados")
mt.ylabel("Tiempo(Segundos)")
mt.title("Elementos ordenados en segundos")

mt.grid(True)

mt.show()
# Out:
# Se demora un total de 15002.0 segundos
# Ordena una cantidad de 1445 elementos

# %% [markdown]
# # Problema 9

# %% [markdown]
# El consumo de energía (en $kWh$) de un *Data Center* puede ser modelado por la función:
#
#  $$E(t) = 50\cdot \log(t + 1) + 200$$
#
# donde $t$ corresponde al tiempo (en horas) desde el inicio del monitoreo.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# 2. Determine el consumo de energía del *Data Center* después de $5$ horas.
# 3. ¿Luego de cuántas horas el consumo será de $350$ kWh?
# 4. Grafique, utilizando la biblioteca *Matplotlib*, la función $E(t)$.

# %%
# 1. La variable dependiente es E(t) que mide la energia usada en kWh, y t el tiempo en horas

# 2. Para esto es solo reemplazar en E(t) el valor de t = 5

def E(t):
    return 50*numpy.log10(t+1)+200

print(f"La cantidad de energia consumida en 5 horas es {E(5):.1f} kWh")

# 3. para esto usamos el metodo fsolve en e

def e(t):
    return 50*numpy.log10(t+1)-150

t = numpy.linspace(0, 96, 1)

sol = fsolve(e, t)

print(f"La cantidad de horas para gastar 350 Kwh es {sol[0]:.1f}")

# 4. 

x = generarEjex(0, 1000, 1)

y = E(x)

mt.plot(x, y)

mt.xlabel("Horas transcurridas")
mt.ylabel("Energia (kWh)")
mt.title("Energia gastada en funcion de horas transcurridas")

mt.grid(True)

mt.show()
# Out:
# La cantidad de energia consumida en 5 horas es 238.9 kWh
# La cantidad de horas para gastar 350 Kwh es 999.0

# %% [markdown]
# # Problema 10

# %% [markdown]
# En gestión de proyectos, es crucial entender cómo se distribuye la carga de trabajo a lo largo del tiempo para planificar recursos, tiempo y esfuerzos de manera eficiente. Un fenómeno común es la disminución exponencial de la carga de trabajo, donde el esfuerzo requerido es mayor al inicio del proyecto y disminuye gradualmente a medida que se completan las tareas principales.
#
# Esta disminución exponencial puede modelarse matemáticamente para predecir y gestionar el trabajo de manera efectiva.
#
# <br>
#
# Un estudio sobre gestión de proyectos sostiene que la carga de trabajo en un proyecto (en porcentaje) puede ser modelada por la función:
#
# $$W(t) = 100e^{-0.1t}$$
#
# donde $t$ corresponde al tiempo transcurrido (en semanas) desde el inicio del proyecto.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# 2. Determine la carga de trabajo al inicio del proyecto.
# 3. ¿Cuál será la carga de trabajo luego de transcurridas $4$ semanas desde el inicio del proyecto?
# 4. Si el proyecto duró $12$ semanas, ¿es correcto afirmar que la carga de trabajo llegó al $20\%$?
# 5. ¿Cuántas semanas han pasado desde el inicio del proyecto para que la carga de trabajo sea de $55\%$?
# 6. Utilizando *Matplotlib*, grafique la función considerando un tiempo máximo de $12$ semanas.

# %%
# 1. La variable independiente t es tiempo medido en semanas y W(t) es ka carga de trabajo porcentual
print(f"1. La variable independiente t es tiempo medido en semanas y W(t) es ka carga de trabajo porcentual")

# 2. Para esto basta evaluar W(0) lo que nos da 100 % cual es la carga de trabajo
print (f"2. Para esto basta evaluar W(0) lo que nos da 100 % cual es la carga de trabajo")

# 3. Para esto basta evaluar W(4) lo que nos da 100/e**0.4
print (f"3. Para esto basta evaluar W(4) lo que nos da {100/numpy.exp(0.4):.1f}%")

# 4.
print(f"4. El proyecto duro 12 semanas, lo que corresponde a W(12), {100/numpy.exp(1.2):.1f}%, la carga de trabajo aun no llego a 20% por lo que esta afirmacion es falsa")

# 5.
print(f"Para saber la cantidad de semanas para saber si la carga de trabajo llego a 55% debemos resolver, {10*numpy.log(100/55):.1f} semanas")  

# 6.
import matplotlib.pyplot as mt
import numpy 

def generarEjex2(domMin, domMax, saltos):
    return numpy.arange(domMin, domMax, saltos)

def w(t):
    return 100*numpy.exp(-0.1*t)

x = generarEjex(0, 12, 1)

y = w(x)

mt.plot(x, y)

mt.xlabel("Semanas")
mt.ylabel("Carga de trabajo(%)")
mt.title("Carga de trabajo en semanas transcurridas")

mt.grid(True)

mt.show()
# Out:
# 1. La variable independiente t es tiempo medido en semanas y W(t) es ka carga de trabajo porcentual
# 2. Para esto basta evaluar W(0) lo que nos da 100 % cual es la carga de trabajo
# 3. Para esto basta evaluar W(4) lo que nos da 67.0%
# 4. El proyecto duro 12 semanas, lo que corresponde a W(12), 30.1%, la carga de trabajo aun no llego a 20% por lo que esta afirmacion es falsa
# Para saber la cantidad de semanas para saber si la carga de trabajo llego a 55% debemos resolver, 6.0 semanas
